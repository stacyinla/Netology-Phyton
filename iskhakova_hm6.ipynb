# %% [markdown]
# ****Домашнее задание по теме «Python для анализа данных: pandas»****
#
# **Задание 1**
#
# *Используем файл keywords.csv.*
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце 'region' пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим 'undefined'.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = {
#
#     'Центр': ['москва', 'тула', 'ярославль'],
#     'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#     'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
# }
#
# Результат классификации запишите в отдельный столбец region.

# %%
#так как в поисковых запросах не было ни одного названия данных городов,
#во всех строках поля region
import pandas as pd

def check_region(keyword):
    geo_data = { 'Центр': ['москва', 'тула', 'ярославль'],
                 'Северо-Запад': ['петербург', 'псков', 'мурманск'],
                 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']  }
    for key, values in geo_data.items():
        for value in values:
            if  value in keyword:
                return key
    return 'undefined'


keywords = pd.read_csv('keywords.csv')
keywords['region'] = keywords['keyword'].apply(check_region)
keywords.head()
# Out:
#          keyword     shows     region
# 0             вк  64292779  undefined
# 1  одноклассники  63810309  undefined
# 2          порно  41747114  undefined
# 3           ютуб  39995567  undefined
# 4      вконтакте  21014195  undefined

# %%
keywords.loc[120:130]
# Out:
#                keyword    shows     region
# 120          дойки ком  1059292  undefined
# 121                аск  1045170  undefined
# 122            мой мир   993332  undefined
# 123              avito   984448  undefined
# 124  викинг фильм 2017   984999  undefined
# 125    школьный портал   982692  undefined
# 126    вк моя страница   979105  undefined
# 127       авито москва   979292      Центр
# 128        спортмастер   968154  undefined
# 129    новости украины   965720  undefined
# 130  онлайн переводчик  3882735  undefined

# %%
keywords.loc[370:375]
# Out:
#                       keyword   shows        region
# 370  авито ру санкт петербург  425134  Северо-Запад
# 371               игры онлайн  588264     undefined
# 372     авито нижний новгород  421310     undefined
# 373                      циан  420257     undefined
# 374                  приват24  420065     undefined
# 375                     rutor  419496     undefined

# %%
keywords.loc[2175:2180]
# Out:
#                                 keyword  shows          region
# 2175                     дром хабаровск  98361  Дальний Восток
# 2176                     авито волжский  97204       undefined
# 2177                          анекс тур  96850       undefined
# 2178  гдз по математике 6 класс мерзляк  98665       undefined
# 2179                            бетсити  96706       undefined
# 2180                        читай город  96816       undefined

# %%
keywords.sort_values(by='region', ascending=False).head(500)
# Out:
#                                                  keyword   shows        region
# 6999                                           москва 24   37459         Центр
# 61986                такси везет москва официальный сайт    6063         Центр
# 43404                          суперджоб москва вакансии    8208         Центр
# 73226                             фанатик спартак москва    5353         Центр
# 68005                                   гостиница москва    5651         Центр
# 7090                                  гисметео ярославль   37008         Центр
# 97382                        комсомольская правда москва    3708         Центр
# 35939            семейный доктор москва официальный сайт    9268         Центр
# 51916                   сбербанк официальный сайт москва    7225         Центр
# 27302                 расписание электричек тверь москва   23272         Центр
# 92506                            эвакуатор москва дешево    4455         Центр
# 63641                                        циан москва    5600         Центр
# 66211                                 интелликаст москва    5337         Центр
# 56895                          авито москва недвижимость   10611         Центр
# 91668                       мвидео тула официальный сайт    3977         Центр
# 63722                             пятерочка акции москва    6213         Центр
# 74222                          совместные покупки москва    4808         Центр
# 98679                                         геи москва    4205         Центр
# 88918         мегафон тарифы москва и московская область    5268         Центр
# 10574                   электронный дневник 76 ярославль   26243         Центр
# 19832                                    рр hh ru москва   15598         Центр
# 81003                    москва я терплю тебя фильм 2016    4468         Центр
# 92578  авито авто с пробегом москва и московская обла...   18149         Центр
# 45976                               доминос пицца москва    7656         Центр
# 61796  авто ру москва и московская область авто с про...   12271         Центр
# 78474                            джоб ру москва вакансии    4563         Центр
# 73640                              детский мир ярославль    4883         Центр
# 51907                  газелькин москва официальный сайт    6617         Центр
# 33886                       динамо москва хоккейный клуб   11123         Центр
# 92635                      запись к врачу тула доктор 71    3939         Центр
# ...                                                  ...     ...           ...
# 73816                                    псковское порно    4895  Северо-Запад
# 90635                       днс мурманск каталог товаров    4030  Северо-Запад
# 27994    санкт петербургский государственный университет   11535  Северо-Запад
# 27548                                 работа в мурманске   11691  Северо-Запад
# 11080                         петербургская недвижимость   25147  Северо-Запад
# 77397                     hh ru санкт петербург вакансии    4659  Северо-Запад
# 96644            каталоги гипермаркетов санкт петербурга    3701  Северо-Запад
# 27992     спортмастер каталог товаров в санкт петербурге   14700  Северо-Запад
# 27069  горный университет санкт петербург официальный...   12061  Северо-Запад
# 16130                          кассир ру санкт петербург   18362  Северо-Запад
# 86193                   карусель каталог санкт петербург    4404  Северо-Запад
# 29397         юлмарт санкт петербург каталог товаров спб   11045  Северо-Запад
# 17360                                     гисметео псков   17500  Северо-Запад
# 84167                        авито псков работа вакансии    4794  Северо-Запад
# 54448             юлмарт санкт петербург каталог товаров    6439  Северо-Запад
# 61653                                    эльдорадо псков    5742  Северо-Запад
# 15940                               санкт петербург банк  174375  Северо-Запад
# 18766                  циан недвижимость санкт петербург   16164  Северо-Запад
# 70227              исаакиевский собор в санкт петербурге    5063  Северо-Запад
# 45875                         гостиницы санкт петербурга    7456  Северо-Запад
# 99808                  полармед мурманск запись на прием    3719  Северо-Запад
# 97413                          kassir ru санкт петербург    3723  Северо-Запад
# 85594                     запись к врачу онлайн мурманск    4347  Северо-Запад
# 66025         почтовый индекс по адресу санкт петербурга    5761  Северо-Запад
# 51611                  холодильник ру в санкт петербурге    6721  Северо-Запад
# 53412                 кари обувь каталог санкт петербург    6472  Северо-Запад
# 70167                                     новости пскова    5036  Северо-Запад
# 84400                                    мурманск погода   17908  Северо-Запад
# 88619   погода в мурманске на неделю на норвежском сайте    4150  Северо-Запад
# 81255             суперджоб ру спб вакансии в петербурге    4351  Северо-Запад
#
# [500 rows x 3 columns]

# %% [markdown]
# **Задание 2**
#
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
#     - оценка 2 и меньше - низкий рейтинг
#     - оценка 4 и меньше - средний рейтинг
#     - оценка 4.5 и 5 - высокий рейтинг
#
# Результат классификации запишите в столбец class

# %%
ml-latest-small/

# %% [markdown]
# **Задание 3**
#
# Посчитайте среднее значение Lifetime киноманов (пользователи, которые поставили 100 и более рейтингов). Под Lifetime понимается разница между максимальным и минимальным значением timestamp для каждого пользователя. Ответ дайте в днях.

# %% [markdown]
# **Задание 4**
#
# Есть мнение, что "раньше снимали настоящее кино, не то что сейчас". Ваша задача проверить это утверждение, используя файлы с рейтингами фильмов из материалов занятия. Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, а пройдемся по следующему алгоритму:
#
# 1. В переменную years запишите список из всех годов с 1950 по 2010.
#
# 2. Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
#     - для каждой строки пройдите по всем годам списка years
#     - если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
#     - если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
#
# 3. Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец 'year'
#
# 4. Посчитайте средний рейтинг всех фильмов для каждого значения столбца 'year' и отсортируйте результат по убыванию рейтинга
